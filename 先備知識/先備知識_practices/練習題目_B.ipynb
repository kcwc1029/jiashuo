# %% [markdown]
# ### Problem. 秒數轉分鐘
#
# 已知秒數(seconds)為 150 秒。
#
# 接著：
#
# * 計算總共有幾分鐘
# * 計算最後剩下幾秒
# * 將結果印出來

# %% [markdown]
# ### Problem. 雞蛋盒問題
#
# 一個雞蛋盒(box_capacity)可以裝 12 顆蛋。
#
# 目前共有(total_eggs) 50 顆蛋。
#
# 接著：
#
# * 計算可以裝滿幾盒
# * 計算最後剩下幾顆蛋
# * 將結果印出來

# %% [markdown]
# ### Problem. 次方計算
#
# 已知：
#
# ```python id="kz6m3f"
# number1 = 3
# number2 = 5
# number3 = 2
# power = 5
# ```
#
# 接著：
#
# * 計算 `number1` 的平方
# * 計算 `number2` 的平方
# * 計算 `number3` 的 `power` 次方
# * 將結果印出來

# %% [markdown]
# ### Problem. 面積與體積
#
# 已知正方形邊長(side)為 4。
#
# 接著：
#
# * 計算正方形面積
# * 計算立方體體積
# * 將結果印出來

# %% [markdown]
# ### Problem. 披薩切片
#
# 一個披薩(total_pizza_slices)共有 8 片。
#
# 現在有(people_count) 5 個人平均分配。
#
# 接著：
#
# * 計算每個人可以分到幾片披薩
# * 計算最後剩下幾片披薩
# * 將結果印出來
