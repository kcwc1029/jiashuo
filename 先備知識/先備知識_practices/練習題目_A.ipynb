# %% [markdown]
# ### Problem. 計算兩數相加
#
# 建立：
# ```
# a = 10
# b = 20
# ```
#
# 輸出兩數相加結果。

# %% [markdown]
# ### Problem. 飲料價格計算
#
# 一杯紅茶(black_tea_price) 35 元。
#
# 今天購買(drink_count) 4 杯。
#
# 接著：
#
# * 計算飲料總金額
# * 將結果印出來

# %% [markdown]
# ### Problem. 計算長方形面積
#
# 已知：
# ```
# width = 10
# height = 5
# ```
# 請輸出長方形面積。

# %% [markdown]
# ### Problem. 計算 BMI
#
# 建立：
# ```
# height = 170
# weight = 60
# ```
#
# BMI 公式：體重 / (身高公尺 ** 2)
#
# > 提示：身高需要先轉公尺

# %% [markdown]
# ### Problem. 時薪計算
#
# 某份工作的時薪(hourly_wage)為 196 元。
#
# 一天工作(work_hours_per_day) 8 小時。
#
# 一個月工作(work_days_per_month) 22 天。
#
# 接著：
#
# * 計算一個月總工時
# * 計算月薪
# * 將結果印出來

# %% [markdown]
# ### Problem. 超商購物平均
#
# 你今天去便利商店買了三樣東西：
#
# 飯糰(rice_ball_price)：39 元
# 奶茶(milk_tea_price)：35 元
# 茶葉蛋(tea_egg_price)：13 元
#
# 接著：
#
# * 計算三樣商品的總金額
# * 計算平均價格
# * 將結果印出來
