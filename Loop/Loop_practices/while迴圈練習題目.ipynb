# %% [markdown]
# ## 練習：
# * [Zerojudge連結](https://drive.google.com/file/d/1eN_zPjlwBLPhgEJoH1WoxhbbBrHcXEaI/view?usp=sharing)

# %% [markdown]
# ### Problem. 燒開水溫度監測器 (認識基本 while 迴圈)
# * 生活情境：用瓦斯爐燒開水時，溫度會慢慢上升，直到達到 100 度水開了，我們才會關火。
# * 題目描述：請建立一個變數 water_temp 代表目前水溫，一開始設定為整數 20。
# * 執行邏輯：建立一個 while 迴圈，設定條件為：當 water_temp 小於 100 時，就持續執行。
# * 輸出規範：在迴圈內部，印出文字：水溫目前為 幾 度，繼續加熱...（請將 幾 替換為 water_temp 的數值）。接著，讓 water_temp 每次增加 20（提示：可以寫成 water_temp += 20）。
# * 當迴圈結束後（寫在迴圈外部），印出：水燒開了，請關火！。
# <!--
# ```python=
# water_temp = 20
#
# while water_temp < 100:
#     print(f"水溫目前為 {water_temp} 度，繼續加熱...")
#     water_temp += 20
#
# print("水燒開了，請關火！")
# ```
# -->

# %% [markdown]
# ### Problem. 傳統市場買菜記帳本 (while 與累加)
# * 生活情境：去菜市場買菜，買一把青菜記一筆、買一條魚記一筆，直到全部買完算總花費。
# * 題目描述：請先建立一個變數 total_cost 用來記錄總花費，初始值設為 0。
# * 接著，顯示提示「請輸入購買金額（輸入 0 代表結束計算）：」，讀取輸入並轉換為整數，存入變數 price。
# * 執行邏輯：建立一個 while 迴圈，條件為：當 price 不等於 0 時，就繼續執行。
# * 輸出規範：在迴圈內部，將 price 的數字加到 total_cost 裡面。接著，再次顯示相同的提示文字讓使用者輸入下一個金額，並更新 price 變數的值。
# * 當迴圈結束後，印出：今天買菜總共花了 多少 元（將 多少 替換為 total_cost 的數字）。
# <!--
# ```python=
# total_cost = 0
# price = int(input("請輸入購買金額（輸入 0 代表結束計算）："))
#
# while price != 0:
#     total_cost += price
#     price = int(input("請輸入購買金額（輸入 0 代表結束計算）："))
#
# print(f"今天買菜總共花了 {total_cost} 元")
# ```
# -->

# %% [markdown]
# ### Problem. 提款機密碼輸入 (無限迴圈與 break)
# * 生活情境：去 ATM 領錢，如果密碼輸入錯誤，機器會一直要求重新輸入，直到輸入正確的密碼為止。
# * 題目描述：請建立一個無限迴圈（使用 while True:）。
# * 執行邏輯與輸入：在迴圈內部，顯示提示「請輸入提款卡密碼：」，讀取使用者的文字輸入，並存入變數 pwd。
# * 輸出規範：在迴圈內部使用 if 判斷式，如果 pwd 等於 1234，則印出：密碼正確，登入成功！，並使用 break 強制離開迴圈。如果不是 1234，則印出：密碼錯誤，請重新輸入。。
# <!--
# ```python=
# while True:
#     pwd = input("請輸入提款卡密碼：")
#
#     if pwd == '1234':
#         print("密碼正確，登入成功！")
#         break
#     else:
#         print("密碼錯誤，請重新輸入。")
# ```
# -->

# %% [markdown]
# ### Problem. 避開禁忌樓層
# * 生活情境：許多醫院的電梯沒有 4 樓，當樓層數字往上跳時，會自動跳過 4 這個數字。
# * 題目描述：建立一個變數 floor 代表樓層，初始值設為 0。
# * 執行邏輯：建立一個 while 迴圈，條件為：當 floor 小於 6 時執行。
# * 輸出規範：在迴圈一開始，先讓 floor 增加 1。接著使用 if 判斷式，如果 floor 等於 4，使用 continue 跳過後面的動作，直接進入下一次迴圈。如果不是 4，則印出：電梯來到 幾 樓（將 幾 替換為 floor）。
# <!--
# ```python=
# floor = 0
#
# while floor < 6:
#     floor += 1
#     if floor == 4:
#         continue
#     print(f"電梯來到 {floor} 樓")
# ```
# -->

# %% [markdown]
# ### Problem. 社區合唱團排隊形 (雙重 while 迴圈)
# 生活情境：合唱團演出要排隊形，總共排 2 排，每一排站 3 個人。我們用程式來畫出位置圖。
# * 題目描述：建立外層變數 row（代表排數），初始值設為 1。
# * 執行邏輯：外層 while 迴圈條件為：當 row 小於等於 2 時執行。
# * 輸出規範：
#     * 在外層迴圈內，建立內層變數 col（代表每排的人數），初始值設為 1。
#     * 建立內層 while 迴圈，條件為：當 col 小於等於 3 時執行。
#     * 在內層迴圈中，印出文字：人，並加上 end=' ' 讓字不要換行。印完後讓 col 增加 1。
#     * 內層迴圈結束後（退回外層迴圈），使用空的 print() 進行換行，並讓 row 增加 1。
# <!--
# ```python=
# row = 1
# while row <= 2:
#     col = 1
#     while col <= 3:
#         print("人", end=' ')
#         col += 1
#     print()
#     row += 1
# ```
# -->

# %% [markdown]
# ### Problem. KTV 點歌系統 (字串條件判斷)
# * 生活情境：在包廂唱歌，點歌機畫面會一直停留在點歌狀態，直到客人按下離開鍵。
# * 題目描述：建立一個變數 song，初始值設定為空字串（即 ''）。
# * 執行邏輯：建立一個 while 迴圈，條件為：當 song 不等於 離開 這個文字時。
# * 輸出規範：在迴圈內，顯示提示「請輸入想唱的歌名（輸入 離開 則關機）：」，讀取輸入存入變數 song。接著使用 if 判斷，如果 song 不等於 離開，就印出：為您播放： 加上剛才輸入的歌名。
# <!--
# ```python=
# song = ''
#
# while song != '離開':
#     song = input("請輸入想唱的歌名（輸入 離開 則關機）：")
#     if song != '離開':
#         print(f"為您播放： {song}")
# ```
# -->

# %% [markdown]
# ### Problem. 尋找電視頻道
# * 生活情境：拿著遙控器一台一台往下轉，想找第 8 台的新聞台，一轉到就會停下來不再往下轉。
# * 題目描述：建立變數 channel 代表頻道號碼，初始值設為 1。
# * 執行邏輯：建立 while 迴圈，條件為：當 channel 小於等於 10 時執行。
# * 輸出規範：在迴圈內部，使用 if 判斷式，如果 channel 等於 8，印出：找到了！停在第 8 台，並使用 break 離開迴圈。如果不是 8，印出：跳過第 幾 台（將 幾 替換為 channel），並讓 channel 增加 1。
# <!--
# ```python=
# channel = 1
#
# while channel <= 10:
#     if channel == 8:
#         print("找到了！停在第 8 台")
#         break
#
#     print(f"跳過第 {channel} 台")
#     channel += 1
# ```
# -->

# %% [markdown]
# ### Problem. 挑選漂亮蘋果 (綜合應用)
# * 生活情境：從一箱蘋果中挑選。遇到壞掉的就丟掉（跳過不算），挑選到又大又紅的就放進籃子，如果覺得累了隨時可以停止挑選。
# * 題目描述：建立一個記錄挑了幾顆蘋果的變數 count，初始值為 0。使用 while True: 建立無限迴圈。
# * 執行邏輯與輸入：顯示提示「這顆蘋果狀況如何？(輸入 壞掉、漂亮 或 休息)：」，並存入變數 status。
# * 輸出規範：
#     * 如果 status 是 休息，印出：今天先挑到這裡，收工！，使用 break 結束迴圈。
#     * 如果 status 是 壞掉，印出：這顆不行，丟掉。，使用 continue 跳過這回合。
#     * 如果 status 是 漂亮，讓 count 增加 1，並印出：放進籃子，目前累積 幾 顆蘋果（將 幾 替換為 count）。
# <!--
# ```python=
# count = 0
#
# while True:
#     status = input("這顆蘋果狀況如何？(輸入 壞掉、漂亮 或 休息)：")
#
#     if status == '休息':
#         print("今天先挑到這裡，收工！")
#         break
#
#     if status == '壞掉':
#         print("這顆不行，丟掉。")
#         continue
#
#     if status == '漂亮':
#         count += 1
#         print(f"放進籃子，目前累積 {count} 顆蘋果")
# ```
# -->
